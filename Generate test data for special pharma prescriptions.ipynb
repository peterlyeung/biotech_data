# %%
import random
import pandas as pd
import uuid
from datetime import datetime, timedelta
import random

# get current date
now = datetime.now()




# list of possible values for each column
gender = ['M', 'F']
birth_year = list(range(1912, 1998))
patient_anon_id = [[str(uuid.uuid4()) for _ in range(10)]]
zip3 = ['123', '456', '789', '012', '345']
status = ['active', 'denied', 'withdrew', 'pending']
drug_name = ['Drug A', 'Drug B', 'Drug C', 'Drug D', 'Drug E']
drug_dosage = ['10mg', '20mg', '30mg', '40mg', '50mg']
dispense_name = ['Specialty Pharmacy 1', 'Specialty Pharmacy 2', 'Specialty Pharmacy 3', 'Specialty Pharmacy 4', 'Specialty Pharmacy 5']
dispense_address = ['123 Main St', '456 Park Ave', '789 Elm St', '012 Oak St', '345 Pine St']
dispense_city = ['City 1', 'City 2', 'City 3', 'City 4', 'City 5']
dispense_state = ['State 1', 'State 2', 'State 3', 'State 4', 'State 5']
# create a list of random dates within the last 2 years
dispense_dates = [now - timedelta(days=random.randint(1, 365*2)) for _ in range(len(df))]
prescriber_name = ['Dr. Smith', 'Dr. Johnson', 'Dr. Williams', 'Dr. Jones', 'Dr. Brown']
payer_name = ['Insurance Company A', 'Insurance Company B', 'Insurance Company C', 'Insurance Company D', 'Insurance Company E']
plan_name = ['Plan A', 'Plan B', 'Plan C', 'Plan D', 'Plan E']

# initialize empty list to store rows of data
rows = []

# loop to generate 100 lines of data
for i in range(1, 101):
    # generate random values for each column
    record_id = i
    gender_val = random.choice(gender)
    birth_year_val = random.choice(birth_year)
    patent_anon_id_val = random.choice(patient_anon_id)
    zip3_val = random.choice(zip3)
    status_val = random.choice(status)
    drug_name_val = random.choice(drug_name)
    drug_dosage_val = random.choice(drug_dosage)
    dispense_name_val = random.choice(dispense_name)
    dispense_address_val = random.choice(dispense_address)
    dispense_city_val = random.choice(dispense_city)
    dispense_state_val = random.choice(dispense_state)
    dispense_date_val = random.choice(dispense_dates)
    prescriber_name_val = random.choice(prescriber_name)
    payer_name_val = random.choice(payer_name)
    plan_name_val = random.choice(plan_name)
    quantity_val = random.randint(1,5)
    # add data for current line as a new row in the list
    rows.append([record_id, gender_val, birth_year_val, patent_anon_id_val, zip3_val, status_val, drug_name_val, drug_dosage_val,dispense_name_val, dispense_address_val, dispense_city_val, dispense_state_val, dispense_date_val, prescriber_name_val, payer_name_val, plan_name_val,quantity_val])

# create dataframe from the list of rows
df = pd.DataFrame(rows, columns=['record_id', 'gender', 'birth_year', 'patent_anon_id_val', 'zip3', 'status', 'drug_name', 'drug_dosage','dispense_name', 'dispense_address', 'dispense_city', 'dispense_state', 'dispense_dates', 'prescriber_name', 'payer_name', 'plan_name','quantity'])

df
# Out:
#     record_id gender  birth_year  \
# 0           1      F        1994
# 1           2      M        1935
# 2           3      F        1941
# 3           4      F        1974
# 4           5      M        1990
# 5           6      M        1983
# 6           7      F        1982
# 7           8      F        1958
# 8           9      M        1973
# 9          10      M        1936
# 10         11      F        1921
# 11         12      F        1980
# 12         13      F        1950
# 13         14      M        1948
# 14         15      M        1933
# 15         16      M        1990
# 16         17      M        1916
# 17         18      F        1960
# 18         19      M        1921
# 19         20      F        1961
# 20         21      M        1996
# 21         22      M        1956
# 22         23      M        1955
# 23         24      M        1918
# 24         25      M        1963
# 25         26      F        1963
# 26         27      F        1959
# 27         28      M        1950
# 28         29      F        1940
# 29         30      M        1948
# ..        ...    ...         ...
# 70         71      M        1954
# 71         72      M        1965
# 72         73      F        1974
# 73         74      F        1989
# 74         75      F        1990
# 75         76      M        1990
# 76         77      M        1945
# 77         78      F        1920
# 78         79      F        1980
# 79         80      F        1993
# 80         81      M        1939
# 81         82      F        1950
# 82         83      M        1918
# 83         84      M        1977
# 84         85      M        1934
# 85         86      F        1948
# 86         87      M        1931
# 87         88      M        1979
# 88         89      F        1964
# 89         90      M        1979
# 90         91      M        1953
# 91         92      F        1923
# 92         93      F        1929
# 93         94      M        1949
# 94         95      F        1922
# 95         96      M        1986
# 96         97      M        1914
# 97         98      M        1949
# 98         99      M        1984
# 99        100      M        1922
#
#                                    patent_anon_id_val zip3    status  \
# 0   [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  345    denied
# 1   [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  123    active
# 2   [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  345    denied
# 3   [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  345   pending
# 4   [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  789    active
# 5   [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  456    active
# 6   [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  012    active
# 7   [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  123    denied
# 8   [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  456    active
# 9   [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  456  withdrew
# 10  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  123  withdrew
# 11  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  012    active
# 12  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  012  withdrew
# 13  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  345    denied
# 14  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  789  withdrew
# 15  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  456    denied
# 16  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  456   pending
# 17  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  012    denied
# 18  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  123    denied
# 19  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  123   pending
# 20  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  345    active
# 21  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  456    active
# 22  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  345  withdrew
# 23  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  345    active
# 24  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  012    active
# 25  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  789   pending
# 26  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  456    active
# 27  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  012  withdrew
# 28  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  789   pending
# 29  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  012    denied
# ..                                                ...  ...       ...
# 70  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  789   pending
# 71  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  012  withdrew
# 72  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  345    active
# 73  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  345   pending
# 74  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  789  withdrew
# 75  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  789  withdrew
# 76  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  012  withdrew
# 77  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  123   pending
# 78  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  456   pending
# 79  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  123   pending
# 80  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  123    active
# 81  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  456    active
# 82  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  345  withdrew
# 83  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  789    active
# 84  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  456    denied
# 85  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  012  withdrew
# 86  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  456    active
# 87  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  789    denied
# 88  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  012    active
# 89  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  789    denied
# 90  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  345    active
# 91  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  789  withdrew
# 92  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  345  withdrew
# 93  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  789    denied
# 94  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  123    active
# 95  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  012  withdrew
# 96  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  789   pending
# 97  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  456    active
# 98  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  012  withdrew
# 99  [f37af557-ee29-44d4-be95-bb2380bf5f36, da8dafe...  345    denied
#
#    drug_name drug_dosage         dispense_name dispense_address dispense_city  \
# 0     Drug C        40mg  Specialty Pharmacy 4      345 Pine St        City 1
# 1     Drug A        20mg  Specialty Pharmacy 4     456 Park Ave        City 3
# 2     Drug B        30mg  Specialty Pharmacy 5      345 Pine St        City 5
# 3     Drug B        30mg  Specialty Pharmacy 5      123 Main St        City 1
# 4     Drug B        40mg  Specialty Pharmacy 5       789 Elm St        City 3
# 5     Drug C        40mg  Specialty Pharmacy 2      123 Main St        City 3
# 6     Drug C        20mg  Specialty Pharmacy 4     456 Park Ave        City 1
# 7     Drug B        40mg  Specialty Pharmacy 4      123 Main St        City 2
# 8     Drug D        40mg  Specialty Pharmacy 4      345 Pine St        City 4
# 9     Drug B        10mg  Specialty Pharmacy 2      123 Main St        City 2
# 10    Drug B        40mg  Specialty Pharmacy 1       789 Elm St        City 1
# 11    Drug A        20mg  Specialty Pharmacy 4      345 Pine St        City 5
# 12    Drug B        50mg  Specialty Pharmacy 4     456 Park Ave        City 4
# 13    Drug A        10mg  Specialty Pharmacy 4     456 Park Ave        City 3
# 14    Drug B        30mg  Specialty Pharmacy 1       012 Oak St        City 2
# 15    Drug B        10mg  Specialty Pharmacy 5      123 Main St        City 5
# 16    Drug C        40mg  Specialty Pharmacy 5      345 Pine St        City 5
# 17    Drug E        10mg  Specialty Pharmacy 2       012 Oak St        City 3
# 18    Drug C        40mg  Specialty Pharmacy 2       789 Elm St        City 4
# 19    Drug E        20mg  Specialty Pharmacy 1      345 Pine St        City 4
# 20    Drug B        20mg  Specialty Pharmacy 4       012 Oak St        City 1
# 21    Drug D        10mg  Specialty Pharmacy 4      345 Pine St        City 2
# 22    Drug D        30mg  Specialty Pharmacy 3       789 Elm St        City 4
# 23    Drug D        20mg  Specialty Pharmacy 1      123 Main St        City 3
# 24    Drug E        50mg  Specialty Pharmacy 5       012 Oak St        City 5
# 25    Drug A        10mg  Specialty Pharmacy 4       012 Oak St        City 5
# 26    Drug D        10mg  Specialty Pharmacy 3      345 Pine St        City 3
# 27    Drug B        30mg  Specialty Pharmacy 3       789 Elm St        City 5
# 28    Drug B        10mg  Specialty Pharmacy 4      123 Main St        City 5
# 29    Drug C        50mg  Specialty Pharmacy 3     456 Park Ave        City 4
# ..       ...         ...                   ...              ...           ...
# 70    Drug E        50mg  Specialty Pharmacy 2     456 Park Ave        City 5
# 71    Drug D        10mg  Specialty Pharmacy 3     456 Park Ave        City 5
# 72    Drug A        30mg  Specialty Pharmacy 2       789 Elm St        City 5
# 73    Drug B        30mg  Specialty Pharmacy 4       789 Elm St        City 3
# 74    Drug C        10mg  Specialty Pharmacy 2       789 Elm St        City 5
# 75    Drug E        30mg  Specialty Pharmacy 1     456 Park Ave        City 3
# 76    Drug D        30mg  Specialty Pharmacy 5      123 Main St        City 1
# 77    Drug C        50mg  Specialty Pharmacy 2       789 Elm St        City 3
# 78    Drug D        30mg  Specialty Pharmacy 3       789 Elm St        City 5
# 79    Drug A        20mg  Specialty Pharmacy 5       789 Elm St        City 4
# 80    Drug D        30mg  Specialty Pharmacy 2       012 Oak St        City 2
# 81    Drug C        40mg  Specialty Pharmacy 4       789 Elm St        City 3
# 82    Drug C        50mg  Specialty Pharmacy 5      123 Main St        City 3
# 83    Drug C        10mg  Specialty Pharmacy 5     456 Park Ave        City 3
# 84    Drug C        50mg  Specialty Pharmacy 4      345 Pine St        City 4
# 85    Drug C        10mg  Specialty Pharmacy 1       789 Elm St        City 3
# 86    Drug C        40mg  Specialty Pharmacy 5       012 Oak St        City 4
# 87    Drug E        20mg  Specialty Pharmacy 2     456 Park Ave        City 1
# 88    Drug B        40mg  Specialty Pharmacy 4     456 Park Ave        City 3
# 89    Drug C        40mg  Specialty Pharmacy 4       789 Elm St        City 5
# 90    Drug B        20mg  Specialty Pharmacy 5     456 Park Ave        City 2
# 91    Drug A        30mg  Specialty Pharmacy 2       789 Elm St        City 4
# 92    Drug E        10mg  Specialty Pharmacy 3      345 Pine St        City 1
# 93    Drug D        50mg  Specialty Pharmacy 1       012 Oak St        City 5
# 94    Drug D        30mg  Specialty Pharmacy 1      123 Main St        City 1
# 95    Drug B        10mg  Specialty Pharmacy 5      123 Main St        City 4
# 96    Drug A        10mg  Specialty Pharmacy 2       012 Oak St        City 3
