# %% [markdown]
# # Specialty Pharma Prescription test data generator

# %%
import random
import pandas as pd
import uuid
from datetime import datetime, timedelta
import random

# get current date
now = datetime.now()




# list of possible values for each column
gender = ['M', 'F']
birth_year = list(range(1912, 1998))
patient_anon_id = [[str(uuid.uuid4()) for _ in range(10)]]
zip3 = ['123', '456', '789', '012', '345']
status = ['active', 'denied', 'withdrew', 'pending']
drug_name = ['Drug A', 'Drug B', 'Drug C', 'Drug D', 'Drug E']
drug_dosage = ['10mg', '20mg', '30mg', '40mg', '50mg']
dispense_name = ['Specialty Pharmacy 1', 'Specialty Pharmacy 2', 'Specialty Pharmacy 3', 'Specialty Pharmacy 4', 'Specialty Pharmacy 5']
dispense_address = ['123 Main St', '456 Park Ave', '789 Elm St', '012 Oak St', '345 Pine St']
dispense_city = ['City 1', 'City 2', 'City 3', 'City 4', 'City 5']
dispense_state = ['State 1', 'State 2', 'State 3', 'State 4', 'State 5']
# create a list of random dates within the last 2 years
dispense_dates = [now - timedelta(days=random.randint(1, 365*2)) for _ in range(len(df))]
prescriber_name = ['Dr. Smith', 'Dr. Johnson', 'Dr. Williams', 'Dr. Jones', 'Dr. Brown']
payer_name = ['Insurance Company A', 'Insurance Company B', 'Insurance Company C', 'Insurance Company D', 'Insurance Company E']
plan_name = ['Plan A', 'Plan B', 'Plan C', 'Plan D', 'Plan E']

# initialize empty list to store rows of data
rows = []

# loop to generate 100 lines of data
for i in range(1, 101):
    # generate random values for each column
    record_id = i
    gender_val = random.choice(gender)
    birth_year_val = random.choice(birth_year)
    patent_anon_id_val = random.choice(patient_anon_id)
    zip3_val = random.choice(zip3)
    status_val = random.choice(status)
    drug_name_val = random.choice(drug_name)
    drug_dosage_val = random.choice(drug_dosage)
    dispense_name_val = random.choice(dispense_name)
    dispense_address_val = random.choice(dispense_address)
    dispense_city_val = random.choice(dispense_city)
    dispense_state_val = random.choice(dispense_state)
    dispense_date_val = random.choice(dispense_dates)
    prescriber_name_val = random.choice(prescriber_name)
    payer_name_val = random.choice(payer_name)
    plan_name_val = random.choice(plan_name)
    quantity_val = random.randint(1,5)
    # add data for current line as a new row in the list
    rows.append([record_id, gender_val, birth_year_val, patent_anon_id_val, zip3_val, status_val, drug_name_val, drug_dosage_val,dispense_name_val, dispense_address_val, dispense_city_val, dispense_state_val, dispense_date_val, prescriber_name_val, payer_name_val, plan_name_val,quantity_val])

# create dataframe from the list of rows
df = pd.DataFrame(rows, columns=['record_id', 'gender', 'birth_year', 'patent_anon_id_val', 'zip3', 'status', 'drug_name', 'drug_dosage','dispense_name', 'dispense_address', 'dispense_city', 'dispense_state', 'dispense_dates', 'prescriber_name', 'payer_name', 'plan_name','quantity'])

df
# Out:
#     record_id gender  birth_year  \
# 0           1      F        1928
# 1           2      F        1987
# 2           3      M        1955
# 3           4      M        1976
# 4           5      M        1913
# 5           6      F        1997
# 6           7      M        1938
# 7           8      F        1990
# 8           9      M        1937
# 9          10      F        1976
# 10         11      F        1920
# 11         12      M        1981
# 12         13      F        1929
# 13         14      M        1955
# 14         15      M        1993
# 15         16      F        1916
# 16         17      F        1982
# 17         18      M        1981
# 18         19      F        1968
# 19         20      F        1964
# 20         21      M        1926
# 21         22      F        1979
# 22         23      M        1963
# 23         24      M        1939
# 24         25      M        1988
# 25         26      F        1937
# 26         27      F        1997
# 27         28      M        1938
# 28         29      F        1916
# 29         30      F        1913
# ..        ...    ...         ...
# 70         71      M        1964
# 71         72      M        1928
# 72         73      F        1951
# 73         74      F        1953
# 74         75      F        1940
# 75         76      M        1934
# 76         77      F        1973
# 77         78      M        1932
# 78         79      F        1936
# 79         80      M        1928
# 80         81      M        1981
# 81         82      F        1929
# 82         83      F        1939
# 83         84      M        1961
# 84         85      M        1983
# 85         86      M        1965
# 86         87      F        1948
# 87         88      M        1932
# 88         89      M        1996
# 89         90      F        1992
# 90         91      F        1992
# 91         92      F        1943
# 92         93      F        1967
# 93         94      M        1975
# 94         95      F        1988
# 95         96      M        1955
# 96         97      M        1952
# 97         98      F        1936
# 98         99      M        1982
# 99        100      F        1991
#
#                                    patent_anon_id_val zip3    status  \
# 0   [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  012  withdrew
# 1   [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  012  withdrew
# 2   [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  456    active
# 3   [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  456   pending
# 4   [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  345  withdrew
# 5   [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  789   pending
# 6   [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  456  withdrew
# 7   [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  789    denied
# 8   [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  012   pending
# 9   [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  789  withdrew
# 10  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  456  withdrew
# 11  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  345   pending
# 12  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  345    active
# 13  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  789  withdrew
# 14  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  123   pending
# 15  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  345    denied
# 16  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  123    active
# 17  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  345    active
# 18  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  456    active
# 19  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  345   pending
# 20  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  012    active
# 21  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  123    active
# 22  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  789    denied
# 23  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  123    denied
# 24  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  123  withdrew
# 25  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  012    denied
# 26  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  345  withdrew
# 27  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  345  withdrew
# 28  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  456  withdrew
# 29  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  345   pending
# ..                                                ...  ...       ...
# 70  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  456  withdrew
# 71  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  123    denied
# 72  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  012   pending
# 73  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  012    denied
# 74  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  012   pending
# 75  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  123    active
# 76  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  123    denied
# 77  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  012    denied
# 78  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  789    active
# 79  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  123    denied
# 80  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  012    active
# 81  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  456  withdrew
# 82  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  012    denied
# 83  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  456  withdrew
# 84  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  456    active
# 85  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  456  withdrew
# 86  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  789   pending
# 87  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  012   pending
# 88  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  012    denied
# 89  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  012   pending
# 90  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  123    denied
# 91  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  012  withdrew
# 92  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  012    denied
# 93  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  345  withdrew
# 94  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  123  withdrew
# 95  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  123    active
# 96  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  012    active
# 97  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  789    denied
# 98  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  345   pending
# 99  [41488e02-7119-482f-887f-709116aa6829, 6c6c5ab...  123   pending
#
#    drug_name drug_dosage         dispense_name dispense_address dispense_city  \
# 0     Drug B        20mg  Specialty Pharmacy 3      123 Main St        City 1
# 1     Drug B        20mg  Specialty Pharmacy 1      123 Main St        City 3
# 2     Drug C        30mg  Specialty Pharmacy 5     456 Park Ave        City 4
# 3     Drug C        10mg  Specialty Pharmacy 5      345 Pine St        City 1
# 4     Drug B        30mg  Specialty Pharmacy 1      123 Main St        City 4
# 5     Drug A        30mg  Specialty Pharmacy 5      123 Main St        City 5
# 6     Drug E        40mg  Specialty Pharmacy 3       012 Oak St        City 4
# 7     Drug A        30mg  Specialty Pharmacy 5     456 Park Ave        City 2
# 8     Drug C        20mg  Specialty Pharmacy 3       012 Oak St        City 5
# 9     Drug D        10mg  Specialty Pharmacy 1       012 Oak St        City 5
# 10    Drug B        50mg  Specialty Pharmacy 1       789 Elm St        City 2
# 11    Drug D        30mg  Specialty Pharmacy 3     456 Park Ave        City 1
# 12    Drug B        50mg  Specialty Pharmacy 1      123 Main St        City 4
# 13    Drug A        10mg  Specialty Pharmacy 2      345 Pine St        City 3
# 14    Drug A        20mg  Specialty Pharmacy 4       012 Oak St        City 1
# 15    Drug D        30mg  Specialty Pharmacy 4       789 Elm St        City 5
# 16    Drug C        40mg  Specialty Pharmacy 5       012 Oak St        City 4
# 17    Drug C        30mg  Specialty Pharmacy 2      345 Pine St        City 4
# 18    Drug A        30mg  Specialty Pharmacy 1       012 Oak St        City 4
# 19    Drug C        30mg  Specialty Pharmacy 1       789 Elm St        City 1
# 20    Drug B        30mg  Specialty Pharmacy 4     456 Park Ave        City 4
# 21    Drug D        20mg  Specialty Pharmacy 2     456 Park Ave        City 3
# 22    Drug A        40mg  Specialty Pharmacy 3      123 Main St        City 1
# 23    Drug B        40mg  Specialty Pharmacy 1       012 Oak St        City 4
# 24    Drug A        20mg  Specialty Pharmacy 4      123 Main St        City 5
# 25    Drug D        30mg  Specialty Pharmacy 5     456 Park Ave        City 2
# 26    Drug D        50mg  Specialty Pharmacy 3       789 Elm St        City 4
# 27    Drug E        20mg  Specialty Pharmacy 2       012 Oak St        City 2
# 28    Drug A        20mg  Specialty Pharmacy 2       789 Elm St        City 5
# 29    Drug A        20mg  Specialty Pharmacy 1      123 Main St        City 4
# ..       ...         ...                   ...              ...           ...
# 70    Drug C        20mg  Specialty Pharmacy 5       789 Elm St        City 1
# 71    Drug E        40mg  Specialty Pharmacy 1     456 Park Ave        City 5
# 72    Drug E        10mg  Specialty Pharmacy 1      345 Pine St        City 1
# 73    Drug D        50mg  Specialty Pharmacy 3       012 Oak St        City 3
# 74    Drug C        50mg  Specialty Pharmacy 1     456 Park Ave        City 2
# 75    Drug D        10mg  Specialty Pharmacy 3      123 Main St        City 1
# 76    Drug B        20mg  Specialty Pharmacy 1     456 Park Ave        City 5
# 77    Drug E        10mg  Specialty Pharmacy 1       789 Elm St        City 2
# 78    Drug D        20mg  Specialty Pharmacy 2       789 Elm St        City 5
# 79    Drug B        30mg  Specialty Pharmacy 3       789 Elm St        City 3
# 80    Drug C        30mg  Specialty Pharmacy 4       012 Oak St        City 1
# 81    Drug E        40mg  Specialty Pharmacy 1       012 Oak St        City 5
# 82    Drug B        10mg  Specialty Pharmacy 1       789 Elm St        City 3
# 83    Drug D        30mg  Specialty Pharmacy 1      345 Pine St        City 3
# 84    Drug C        50mg  Specialty Pharmacy 1       789 Elm St        City 3
# 85    Drug B        30mg  Specialty Pharmacy 2       012 Oak St        City 5
# 86    Drug B        40mg  Specialty Pharmacy 1       789 Elm St        City 2
# 87    Drug B        50mg  Specialty Pharmacy 4       789 Elm St        City 2
# 88    Drug B        20mg  Specialty Pharmacy 4      345 Pine St        City 4
# 89    Drug C        50mg  Specialty Pharmacy 1       789 Elm St        City 2
# 90    Drug B        10mg  Specialty Pharmacy 1       012 Oak St        City 1
# 91    Drug A        30mg  Specialty Pharmacy 1      123 Main St        City 2
# 92    Drug A        20mg  Specialty Pharmacy 1       789 Elm St        City 4
# 93    Drug E        20mg  Specialty Pharmacy 3       789 Elm St        City 4
# 94    Drug C        20mg  Specialty Pharmacy 5      345 Pine St        City 1
# 95    Drug B        10mg  Specialty Pharmacy 3      123 Main St        City 5
